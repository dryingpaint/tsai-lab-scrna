# %% [markdown]
# # Pseudobulk method for differential gene analysis
#
# Aggregate per donor
# For each cluster (cell type)
# Ignore the mixed clusters for now
# DO: Astrocytes, excit, inhib, endos
#
# plot heatmap to show upregulated and downregulated egnes
# - plot volcano for log2fold change and p-value
#
# Do differential gene expression analysis. Start with Deseq2.

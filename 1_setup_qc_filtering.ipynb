# %% [markdown]
# # Notebook 1: Setup, QC & Filtering
#
# **Cell Annotation Pipeline - Part 1 of 3**
#
# This notebook handles the initial data loading and quality control steps.
#
# **Stages covered:**
# 1. Data Loading & Integration
# 2. QC Metrics Calculation & Visualization
# 3. Doublet Detection (per-sample)
# 4. Cell & Gene Filtering
#
# **📤 Output:** `qc_filtered_data.h5ad` (filtered cells with QC metadata)
#
# **➡️ Next:** `2_clustering_markers.ipynb`
#
# ---
